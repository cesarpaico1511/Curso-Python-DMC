# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpaico1511/Curso-Python-DMC/blob/main/ejercicio1_cp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este es el primer ejecicio de Python

# %%
5 + 5
# Out:
# 10
